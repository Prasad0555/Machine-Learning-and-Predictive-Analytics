# %% [markdown]
# # Vitual Internship Program (VIP) by AINE AI as a Data Science Intern 2021

# %% [markdown]
# # Project: Machine Learning for Predictive Analytics

# %% [markdown]
# ## import the relevent package

# %%
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Setting the working directory

# %%
# Import data and perform processing 
import os as os

# %%
os.chdir('C:\\Users\\MyPC\\Desktop\\AINE AI Intership Projects\Project 8 - Machine learning and Predictive Analytics\\Telecom Data - Machine Learning')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\MyPC\\Desktop\\AINE AI Intership Projects\\Project 8 - Machine learning and Predictive Analytics\\Telecom Data - Machine Learning'

# %%
os.listdir()
# Out:
# ['Log_ROC.png', 'Telecom - Prediction Data.csv', 'Telecom Data.csv']

# %%
# read the dataset
df = pd.read_csv("Telecom Data.csv")
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             50891 non-null  float64
#  3   MonthlyMinutes             50891 non-null  float64
#  4   TotalRecurringCharge       50891 non-null  float64
#  5   DirectorAssistedCalls      50891 non-null  float64
#  6   OverageMinutes             50891 non-null  float64
#  7   RoamingCalls               50891 non-null  float64
#  8   PercChangeMinutes          50680 non-null  float64
#  9   PercChangeRevenues         50680 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
# ...

# %%
df.shape
# Out:
# (51047, 58)

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'MonthlyRevenue', 'MonthlyMinutes',
#        'TotalRecurringCharge', 'DirectorAssistedCalls', 'OverageMinutes',
#        'RoamingCalls', 'PercChangeMinutes', 'PercChangeRevenues',
#        'DroppedCalls', 'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls',
#        'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls', 'InboundCalls',
#        'PeakCallsInOut', 'OffPeakCallsInOut', 'DroppedBlockedCalls',
#        'CallForwardingCalls', 'CallWaitingCalls', 'MonthsInService',
#        'UniqueSubs', 'ActiveSubs', 'ServiceArea', 'Handsets', 'HandsetModels',
#        'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2', 'ChildrenInHH',
#        'HandsetRefurbished', 'HandsetWebCapable', 'TruckOwner', 'RVOwner',
#        'Homeownership', 'BuysViaMailOrder', 'RespondsToMailOffers',
#        'OptOutMailings', 'NonUSTravel', 'OwnsComputer', 'HasCreditCard',
#        'RetentionCalls', 'RetentionOffersAccepted', 'NewCellphoneUser',
# ...

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25             0.0           0.0             -157.0
# 1                   0.00             0.0           0.0               -4.0
# 2                   0.00             0.0           0.0               -2.0
# 3                   1.24             0.0           0.0              157.0
# 4                   0.00             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %% [markdown]
# ## Detect and resolve problems in the data (Missing value, Outliers, Unexpected value, etc.)

# %%
# using heatmap to figure out missing data if any
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)

# %%
df.isnull().sum()
# Out:
# CustomerID                     0
# Churn                          0
# MonthlyRevenue               156
# MonthlyMinutes               156
# TotalRecurringCharge         156
# DirectorAssistedCalls        156
# OverageMinutes               156
# RoamingCalls                 156
# PercChangeMinutes            367
# PercChangeRevenues           367
# DroppedCalls                   0
# BlockedCalls                   0
# UnansweredCalls                0
# CustomerCareCalls              0
# ThreewayCalls                  0
# ReceivedCalls                  0
# OutboundCalls                  0
# InboundCalls                   0
# PeakCallsInOut                 0
# OffPeakCallsInOut              0
# DroppedBlockedCalls            0
# CallForwardingCalls            0
# CallWaitingCalls               0
# MonthsInService                0
# UniqueSubs                     0
# ActiveSubs                     0
# ServiceArea                   24
# Handsets                       1
# ...

# %%
# checking the percentage of missing values
missing = df.isnull().sum()/len(df)
missing
# Out:
# CustomerID                   0.000000
# Churn                        0.000000
# MonthlyRevenue               0.003056
# MonthlyMinutes               0.003056
# TotalRecurringCharge         0.003056
# DirectorAssistedCalls        0.003056
# OverageMinutes               0.003056
# RoamingCalls                 0.003056
# PercChangeMinutes            0.007189
# PercChangeRevenues           0.007189
# DroppedCalls                 0.000000
# BlockedCalls                 0.000000
# UnansweredCalls              0.000000
# CustomerCareCalls            0.000000
# ThreewayCalls                0.000000
# ReceivedCalls                0.000000
# OutboundCalls                0.000000
# InboundCalls                 0.000000
# PeakCallsInOut               0.000000
# OffPeakCallsInOut            0.000000
# DroppedBlockedCalls          0.000000
# CallForwardingCalls          0.000000
# CallWaitingCalls             0.000000
# MonthsInService              0.000000
# UniqueSubs                   0.000000
# ...

# %%
# we are going to look at the frequency of the ServiceArea and we are trying to figure out which is the modal class
df['ServiceArea'].value_counts()
# Out:
# NYCBRO917    1684
# HOUHOU281    1510
# DALDAL214    1498
# NYCMAN917    1182
# APCFCH703     783
#              ...
# NMXPLA806       1
# VAHSTA540       1
# OHIBUT419       1
# INHKOK765       1
# PHIBRI856       1
# Name: ServiceArea, Length: 747, dtype: int64

# %%
# filling the missing values with the modal class
df['ServiceArea'].fillna('NYCBRO917',inplace=True)

# %% [markdown]
# ## Checking the distribution for some of numerical variables

# %%
import seaborn as sns

sns.distplot(df['MonthlyRevenue'])

plt.show() 

# showing right skewed distribution

# %%
import seaborn as sns

sns.distplot(df['RoamingCalls'])

plt.show()

# %%
import seaborn as sns

sns.distplot(df['AgeHH2'])

plt.show()

# %% [markdown]
# ## Missing value imputation for the numerical variables

# %%
# compute the median value for MonthlyRevenue 
np.nanmedian(df['MonthlyRevenue'])
# Out:
# 48.46

# %%
np.nanmedian(df['MonthlyMinutes'])
# Out:
# 366.0

# %%
np.nanmedian(df['TotalRecurringCharge'])
# Out:
# 45.0

# %%
np.nanmedian(df['DirectorAssistedCalls'])
# Out:
# 0.25

# %%
np.nanmedian(df['OverageMinutes'])
# Out:
# 3.0

# %%
np.nanmedian(df['RoamingCalls'])
# Out:
# 0.0

# %%
np.nanmedian(df['PercChangeMinutes'])
# Out:
# -5.0

# %%
np.nanmedian(df['PercChangeRevenues'])
# Out:
# -0.3

# %%
np.nanmedian(df['Handsets'])
# Out:
# 1.0

# %%
np.nanmedian(df['HandsetModels'])
# Out:
# 1.0

# %%
np.nanmedian(df['CurrentEquipmentDays'])
# Out:
# 329.0

# %%
np.nanmedian(df['AgeHH1'])
# Out:
# 36.0

# %%
np.nanmedian(df['AgeHH2'])
# Out:
# 0.0

# %%
# Filling the missing values with median
df['MonthlyRevenue'].fillna(48.46,inplace=True)

df['MonthlyMinutes'].fillna(366.0,inplace=True)

df['TotalRecurringCharge'].fillna(45.0,inplace=True)

df['DirectorAssistedCalls'].fillna(0.25,inplace=True)

df['OverageMinutes'].fillna(3.0,inplace=True)

df['RoamingCalls'].fillna(0.0,inplace=True)

df['PercChangeMinutes'].fillna(-5.0,inplace=True)

df['PercChangeRevenues'].fillna(-3.0,inplace=True)

df['Handsets'].fillna(1.0,inplace=True)

df['HandsetModels'].fillna(1.0,inplace=True)

df['CurrentEquipmentDays'].fillna(329.0,inplace=True)

df['AgeHH1'].fillna(36.0,inplace=True)

df['AgeHH2'].fillna(0.0,inplace=True)

# %%
# again checking the missing values if any
df.isnull().sum()
# Out:
# CustomerID                   0
# Churn                        0
# MonthlyRevenue               0
# MonthlyMinutes               0
# TotalRecurringCharge         0
# DirectorAssistedCalls        0
# OverageMinutes               0
# RoamingCalls                 0
# PercChangeMinutes            0
# PercChangeRevenues           0
# DroppedCalls                 0
# BlockedCalls                 0
# UnansweredCalls              0
# CustomerCareCalls            0
# ThreewayCalls                0
# ReceivedCalls                0
# OutboundCalls                0
# InboundCalls                 0
# PeakCallsInOut               0
# OffPeakCallsInOut            0
# DroppedBlockedCalls          0
# CallForwardingCalls          0
# CallWaitingCalls             0
# MonthsInService              0
# UniqueSubs                   0
# ActiveSubs                   0
# ServiceArea                  0
# Handsets                     0
# HandsetModels                0
# CurrentEquipmentDays         0
# ...

# %%
df['HandsetPrice']=df['HandsetPrice'].map({"Unknown":0})

# %%
df.columns
# Out:
# Index(['CustomerID', 'Churn', 'MonthlyRevenue', 'MonthlyMinutes',
#        'TotalRecurringCharge', 'DirectorAssistedCalls', 'OverageMinutes',
#        'RoamingCalls', 'PercChangeMinutes', 'PercChangeRevenues',
#        'DroppedCalls', 'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls',
#        'ThreewayCalls', 'ReceivedCalls', 'OutboundCalls', 'InboundCalls',
#        'PeakCallsInOut', 'OffPeakCallsInOut', 'DroppedBlockedCalls',
#        'CallForwardingCalls', 'CallWaitingCalls', 'MonthsInService',
#        'UniqueSubs', 'ActiveSubs', 'ServiceArea', 'Handsets', 'HandsetModels',
#        'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2', 'ChildrenInHH',
#        'HandsetRefurbished', 'HandsetWebCapable', 'TruckOwner', 'RVOwner',
#        'Homeownership', 'BuysViaMailOrder', 'RespondsToMailOffers',
#        'OptOutMailings', 'NonUSTravel', 'OwnsComputer', 'HasCreditCard',
#        'RetentionCalls', 'RetentionOffersAccepted', 'NewCellphoneUser',
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             51047 non-null  float64
#  3   MonthlyMinutes             51047 non-null  float64
#  4   TotalRecurringCharge       51047 non-null  float64
#  5   DirectorAssistedCalls      51047 non-null  float64
#  6   OverageMinutes             51047 non-null  float64
#  7   RoamingCalls               51047 non-null  float64
#  8   PercChangeMinutes          51047 non-null  float64
#  9   PercChangeRevenues         51047 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
# ...

# %%
# Number of customers with zero monthly revenue?
x = df['CustomerID']
y = df['MonthlyRevenue']==0

# %%
plt.scatter(x,y,color="orange")

plt.title("Relationship between CustomerID and MonthlyRevenue")

plt.xlabel("CustomerID")

plt.ylabel("MonthlyRevenue")
# Out:
# Text(0, 0.5, 'MonthlyRevenue')

# %%
# Number of customers with missing values percentage > 5%
missing = df['CustomerID'].isnull().sum()/len(df)
missing
# Out:
# 0.0

# %% [markdown]
# ## Outliers Treatment

# %%
# Remove outliers for columns ‘UniqueSubs’
import seaborn as sns
sns.boxplot(x=df['UniqueSubs'])

# %%
Q1 = df.UniqueSubs.quantile(0.25)
Q3 = df.UniqueSubs.quantile(0.75)
Q1,Q3
# Out:
# (1.0, 2.0)

# %%
IQR = Q3 - Q1
IQR
# Out:
# 1.0

# %%
lower_limit = Q1 - 1.5*IQR
upper_limit = Q3 + 1.5*IQR
lower_limit,upper_limit
# Out:
# (-0.5, 3.5)

# %%
df[(df.UniqueSubs<lower_limit)|(df.UniqueSubs>upper_limit)]
# Out:
#        CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 11        3000058    No          212.51          1972.0                  85.0
# 30        3000190   Yes           78.29           852.0                  85.0
# 61        3000406    No          114.13          1650.0                  83.0
# 65        3000422    No           95.17           161.0                  89.0
# 66        3000426   Yes           90.61          1151.0                  95.0
# ...           ...   ...             ...             ...                   ...
# 50584     3396302    No           69.04           974.0                  60.0
# 50733     3397506   Yes           87.49             0.0                  97.0
# 50917     3398998   Yes           48.46           366.0                  45.0
# 50947     3399222    No           48.46           366.0                  45.0
# 50973     3399414    No           48.46           366.0                  45.0
#
# ...

# %%
df['UniqueSubs'] = df[(df.UniqueSubs>lower_limit)&(df.UniqueSubs<upper_limit)]
df['UniqueSubs']
# Out:
# 0              3e+06
# 1        3.00001e+06
# 2        3.00001e+06
# 3        3.00002e+06
# 4        3.00003e+06
#             ...
# 51042    3.39996e+06
# 51043    3.39997e+06
# 51044    3.39998e+06
# 51045    3.39999e+06
# 51046    3.39999e+06
# Name: UniqueSubs, Length: 51047, dtype: object

# %%
sns.boxplot(x=df['UniqueSubs'])

# %%
# Remove outliers for columns ‘DirectorAssistedCalls’
sns.boxplot(x=df['DirectorAssistedCalls'])

# %%
df[(df.DirectorAssistedCalls<lower_limit)|(df.DirectorAssistedCalls>upper_limit)]
# Out:
#        CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 50        3000330    No          196.76          3479.0                  85.0
# 51        3000346    No           79.44           831.0                  75.0
# 77        3000510    No          281.33          3808.0                 183.0
# 78        3000514    No           97.83          1670.0                  83.0
# 82        3000554    No          104.75          1166.0                  75.0
# ...           ...   ...             ...             ...                   ...
# 50905     3398898    No          123.28           518.0                  45.0
# 50951     3399242    No           61.71           372.0                  35.0
# 50983     3399490   Yes          534.93          4719.0                  10.0
# 51003     3399630    No          130.55          2437.0                  75.0
# 51020     3399778    No          109.50           603.0                  43.0
#
# ...

# %%
df['DirectorAssistedCalls'] = df[(df.DirectorAssistedCalls>lower_limit)&(df.DirectorAssistedCalls<upper_limit)]
df['DirectorAssistedCalls']
# Out:
# 0              3e+06
# 1        3.00001e+06
# 2        3.00001e+06
# 3        3.00002e+06
# 4        3.00003e+06
#             ...
# 51042    3.39996e+06
# 51043    3.39997e+06
# 51044    3.39998e+06
# 51045    3.39999e+06
# 51046    3.39999e+06
# Name: DirectorAssistedCalls, Length: 51047, dtype: object

# %%
sns.boxplot(x=df['DirectorAssistedCalls'])

# %% [markdown]
# ## Perform exploratory analysis to analyze customer churn

# %%
#use scatter plot to find the correlation between monthly revenue and overage minutes
sns.scatterplot(x = 'MonthlyRevenue', y = 'MonthlyMinutes', data = df)

# %% [markdown]
# here we can see linear trend bit. Here MonthlyRevenue incresing with MonthlyMinutes

# %%
# Does high number of active subscribers lead to low monthly revenue?
sns.catplot(x='ActiveSubs',y ='MonthlyRevenue',data=df)

# %% [markdown]
# Here we can see that high number of active subs have low monthly revenue for ex: here activesubs is 53 has monthlyreveue somewhere 100

# %%
# Does credit rating have an impact in churn rate?
sns.countplot(x='Churn',hue='CreditRating',data=df)

# %% [markdown]
# wherever the Customer is Churned the creditrating is low

# %% [markdown]
# ## Some more visualization to get understanding about the data

# %%
x = df['AgeHH1']
y = df['AgeHH2']

# %%
# check the relationship between the AgeHH1 and AgeHH2 using a scatter plot
plt.scatter(x,y,color="orange")

plt.title("Relationship between AgeHH1 and AgeHH2")

plt.xlabel("AgeHH1")

plt.ylabel("AgeHH2")
# Out:
# Text(0, 0.5, 'AgeHH2')

# %%
x = df['MonthlyRevenue']
y = df['TotalRecurringCharge']

# %%
plt.scatter(x,y,color="blue")

plt.title("Relationship between MonthlyRevenue and TotalRecurringCharge")

plt.xlabel("MonthlyRevenue")

plt.ylabel("TotalRecurringCharge")
# Out:
# Text(0, 0.5, 'TotalRecurringCharge')

# %%
x = df['MonthsInService']
y = df['CustomerCareCalls']

# %%
plt.scatter(x,y,color="yellow")

plt.title("Relationship between MonthsInService and CustomerCareCalls")

plt.xlabel("MonthsInService")

plt.ylabel("CustomerCareCalls")
# Out:
# Text(0, 0.5, 'CustomerCareCalls')

# %%
# calculating correlation among numeric variable
corr_matrix = df.corr()

# plot correlation matrix
plt.figure(figsize=(20,20))

sns.heatmap(corr_matrix,cmap='Spectral',annot=True);

# %%
sns.pairplot(df.iloc[:,2:6],diag_kind="kde")

# %%
sns.pairplot(df.iloc[:,6:11],diag_kind="hist")

# %%
# do a count check for the categorical variable
sns.countplot(x="Churn",data=df)
plt.show()

# %%
sns.countplot(x="Churn",hue="CreditRating",data=df)

# %%
sns.countplot(x="Churn",hue="Occupation",data=df)

# %%
sns.countplot(x="Churn",hue="MaritalStatus",data=df)

# %%
sns.countplot(x="Churn",hue="OwnsComputer",data=df)

# %% [markdown]
# ## Create additional features to help predict churn

# %%
#wrapper function to create additional features for churn prediction
def create_features(df):
    
    #3.1 Percent of current active subs over total subs
    df['perc_active_subs'] = df['ActiveSubs'] / df['UniqueSubs']
    
    #3.2 Percent of recurrent charge to monthly charge
    #type your code here to create a new column in cust_df
    df['perc_recurrent_charge']=df['MonthsInService'] / df['TotalRecurringCharge']
    
    #3.3 Percent of overage minutes over total monthly minutes
    #type your code here to create a new column in cust_df
    df['perc_overage_minutes']=df['OverageMinutes'] / df['MonthlyMinutes']

    
    return df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51047 entries, 0 to 51046
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   CustomerID                 51047 non-null  int64
#  1   Churn                      51047 non-null  object
#  2   MonthlyRevenue             51047 non-null  float64
#  3   MonthlyMinutes             51047 non-null  float64
#  4   TotalRecurringCharge       51047 non-null  float64
#  5   DirectorAssistedCalls      47893 non-null  object
#  6   OverageMinutes             51047 non-null  float64
#  7   RoamingCalls               51047 non-null  float64
#  8   PercChangeMinutes          51047 non-null  float64
#  9   PercChangeRevenues         51047 non-null  float64
#  10  DroppedCalls               51047 non-null  float64
#  11  BlockedCalls               51047 non-null  float64
#  12  UnansweredCalls            51047 non-null  float64
# ...

# %%
df.head()
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes           24.00           219.0                  22.0
# 1     3000010   Yes           16.99            10.0                  17.0
# 2     3000014    No           38.00             8.0                  38.0
# 3     3000022    No           82.28          1312.0                  75.0
# 4     3000026   Yes           17.14             0.0                  17.0
#
#   DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                 3e+06             0.0           0.0             -157.0
# 1           3.00001e+06             0.0           0.0               -4.0
# 2           3.00001e+06             0.0           0.0               -2.0
# 3           3.00002e+06             0.0           0.0              157.0
# 4           3.00003e+06             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
# List of variables to map

varlist =  ['Churn']

# Defining the map function
def binary_map(x):
    return x.map({'Yes': 1, "No": 0})

# Applying the function to the housing list
df[varlist] = df[varlist].apply(binary_map)

# %%
df.head()
# Out:
#    CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002      1           24.00           219.0                  22.0
# 1     3000010      1           16.99            10.0                  17.0
# 2     3000014      0           38.00             8.0                  38.0
# 3     3000022      0           82.28          1312.0                  75.0
# 4     3000026      1           17.14             0.0                  17.0
#
#   DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                 3e+06             0.0           0.0             -157.0
# 1           3.00001e+06             0.0           0.0               -4.0
# 2           3.00001e+06             0.0           0.0               -2.0
# 3           3.00002e+06             0.0           0.0              157.0
# 4           3.00003e+06             0.0           0.0                0.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
# dropping the customere id column
df.drop(columns='CustomerID',inplace=True)

# %%
df.head()
# Out:
#    Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0      1           24.00           219.0                  22.0
# 1      1           16.99            10.0                  17.0
# 2      0           38.00             8.0                  38.0
# 3      0           82.28          1312.0                  75.0
# 4      1           17.14             0.0                  17.0
#
#   DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                 3e+06             0.0           0.0             -157.0
# 1           3.00001e+06             0.0           0.0               -4.0
# 2           3.00001e+06             0.0           0.0               -2.0
# 3           3.00002e+06             0.0           0.0              157.0
# 4           3.00003e+06             0.0           0.0                0.0
#
#    PercChangeRevenues  DroppedCalls  ...  ReferralsMadeBySubscriber  \
# 0               -19.0           0.7  ...                          0
# ...

# %%
# filling the missing values with 0
df=df.replace(np.NaN, 0)

# %%
df.head()
# Out:
#    Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0      1           24.00           219.0                  22.0
# 1      1           16.99            10.0                  17.0
# 2      0           38.00             8.0                  38.0
# 3      0           82.28          1312.0                  75.0
# 4      1           17.14             0.0                  17.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0              3000002.0             0.0           0.0             -157.0
# 1              3000010.0             0.0           0.0               -4.0
# 2              3000014.0             0.0           0.0               -2.0
# 3              3000022.0             0.0           0.0              157.0
# 4              3000026.0             0.0           0.0                0.0
#
#    PercChangeRevenues  DroppedCalls  ...  ReferralsMadeBySubscriber  \
# 0               -19.0           0.7  ...                          0
# ...

# %%
# create a dummy variable
df = pd.get_dummies(df)

# %%
df.shape
# Out:
# (51047, 837)

# %% [markdown]
# ## Build classification model to predict customer churn month in advance

# %%
# input and output
x = df.drop(['Churn'], axis=1)
y = df['Churn']

# %%
y.shape
# Out:
# (51047,)

# %%
#Train - test split to train and test model accuracy
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0)

#Feature scaling for all continuous variable
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_scaled = sc.fit_transform(x)

# %% [markdown]
# ## Build a simple logistic regression model to predict churn and evaluate model accuracy on test data set

# %%
from sklearn.linear_model import LogisticRegression
log_reg= LogisticRegression()

# %%
# training the 
log_reg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
df1 = pd.read_csv("Telecom - Prediction Data.csv")
df1.head()
# Out:
#    CustomerID  Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000006    NaN           57.49           483.0                  37.0
# 1     3000018    NaN           55.23           570.0                  72.0
# 2     3000034    NaN           97.34          1039.0                  50.0
# 3     3000070    NaN           35.59           153.0                  30.0
# 4     3000074    NaN           55.27          1213.0                  50.0
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                   0.25            23.0           0.0              532.0
# 1                   0.00             0.0           0.0               38.0
# 2                   4.95           420.0           0.0              198.0
# 3                   0.00            16.0           0.0               30.0
# 4                   0.74             0.0           1.3              169.0
#
#    PercChangeRevenues  ...  ReferralsMadeBySubscriber  IncomeGroup  \
# ...

# %%
x = df1.drop(['Churn'],axis=1)
y = df1['Churn']

# %%
x.isnull().sum()
# Out:
# CustomerID                     0
# MonthlyRevenue                60
# MonthlyMinutes                60
# TotalRecurringCharge          60
# DirectorAssistedCalls         60
# OverageMinutes                60
# RoamingCalls                  60
# PercChangeMinutes            135
# PercChangeRevenues           135
# DroppedCalls                   0
# BlockedCalls                   0
# UnansweredCalls                0
# CustomerCareCalls              0
# ThreewayCalls                  0
# ReceivedCalls                  0
# OutboundCalls                  0
# InboundCalls                   0
# PeakCallsInOut                 0
# OffPeakCallsInOut              0
# DroppedBlockedCalls            0
# CallForwardingCalls            0
# CallWaitingCalls               0
# MonthsInService                0
# UniqueSubs                     0
# ActiveSubs                     0
# ServiceArea                    4
# Handsets                       0
# HandsetModels                  0
# ...

# %%
# filling the missing values with median
np.nanmedian(x['MonthlyRevenue'])
# Out:
# 48.665

# %%
np.nanmedian(x['MonthlyMinutes'])
# Out:
# 365.0

# %%
np.nanmedian(x['TotalRecurringCharge'])
# Out:
# 45.0

# %%
np.nanmedian(x['DirectorAssistedCalls'])
# Out:
# 0.25

# %%
np.nanmedian(x['OverageMinutes'])
# Out:
# 2.0

# %%
np.nanmedian(x['RoamingCalls'])
# Out:
# 0.0

# %%
np.nanmedian(x['PercChangeMinutes'])
# Out:
# -4.0

# %%
np.nanmedian(x['PercChangeRevenues'])
# Out:
# -0.3

# %%
np.nanmedian(x['AgeHH1'])
# Out:
# 36.0

# %%
np.nanmedian(x['AgeHH2'])
# Out:
# 0.0

# %%
x['MonthlyRevenue'].fillna(48.665,inplace=True)

x['MonthlyMinutes'].fillna(365.0,inplace=True)

x['TotalRecurringCharge'].fillna(45.0,inplace=True)

x['DirectorAssistedCalls'].fillna(0.25,inplace=True)

x['OverageMinutes'].fillna(2.0,inplace=True)

x['RoamingCalls'].fillna(0.0,inplace=True)

x['PercChangeMinutes'].fillna(-4.0,inplace=True)

x['PercChangeRevenues'].fillna(-0.3,inplace=True)

x['AgeHH1'].fillna(36.0,inplace=True)

x['AgeHH2'].fillna(0.0,inplace=True)

# %%
# dropping the customere id column
x.drop(columns='CustomerID',inplace=True)

# %%
x = pd.get_dummies(x)

# %%
x.isnull().sum()
# Out:
# MonthlyRevenue           0
# MonthlyMinutes           0
# TotalRecurringCharge     0
# DirectorAssistedCalls    0
# OverageMinutes           0
#                         ..
# Occupation_Self          0
# Occupation_Student       0
# MaritalStatus_No         0
# MaritalStatus_Unknown    0
# MaritalStatus_Yes        0
# Length: 762, dtype: int64

# %%
x_test.shape
# Out:
# (15315, 836)

# %%
x.shape
# Out:
# (20000, 762)

# %%
y_pred = log_reg.predict(x_test)
#print('Accuracy of logistic regression classifier on test set: {:.2f}'.format(log_reg.score(x_test, y_test)))

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[10974     1]
#  [ 4340     0]]

# %% [markdown]
# ## Compute precision, recall, F-measure and support

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      1.00      0.83     10975
#            1       0.00      0.00      0.00      4340
#
#     accuracy                           0.72     15315
#    macro avg       0.36      0.50      0.42     15315
# weighted avg       0.51      0.72      0.60     15315

# %%
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
logit_roc_auc = roc_auc_score(y_test, log_reg.predict(x_test))
fpr, tpr, thresholds = roc_curve(y_test, log_reg.predict_proba(x_test)[:,1])
plt.figure()
plt.plot(fpr, tpr, label='Logistic Regression (area = %0.2f)' % logit_roc_auc)
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.savefig('Log_ROC')
plt.show()

# %% [markdown]
# ## Build Random Forest classifier to compare model accuracy over the logistic regression model

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7211230819458048

# %% [markdown]
# ## Compute precision, recall, F-measure and support

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.99      0.84     10975
#            1       0.60      0.05      0.09      4340
#
#     accuracy                           0.72     15315
#    macro avg       0.66      0.52      0.46     15315
# weighted avg       0.69      0.72      0.62     15315

# %% [markdown]
# here we can see that Random forest Classifier performs well, it showing the accuracy 73% whereas logistic regression gives the accuracy 72%

# %% [markdown]
# ## Identify most important features impacting churn

# %%
# Type your code here to plot the top 20 important predictor features impacting churn using the Random Forest model created
df = pd.Series(clf.feature_importances_, index=x_train.columns)
df.head(20)
# Out:
# MonthlyRevenue           0.032054
# MonthlyMinutes           0.034371
# TotalRecurringCharge     0.025190
# DirectorAssistedCalls    0.033393
# OverageMinutes           0.021914
# RoamingCalls             0.015947
# PercChangeMinutes        0.035479
# PercChangeRevenues       0.031360
# DroppedCalls             0.023882
# BlockedCalls             0.021614
# UnansweredCalls          0.027640
# CustomerCareCalls        0.015807
# ThreewayCalls            0.009519
# ReceivedCalls            0.027428
# OutboundCalls            0.026747
# InboundCalls             0.021794
# PeakCallsInOut           0.028466
# OffPeakCallsInOut        0.028650
# DroppedBlockedCalls      0.025684
# CallForwardingCalls      0.000409
# dtype: float64
